# %%
import pandas as pd
import numpy as np
from numpy import mean
from numpy import std
import keras
from sklearn.impute import KNNImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.datasets import make_multilabel_classification
from sklearn.model_selection import RepeatedKFold
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras import layers
from keras import regularizers
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import time

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing Data

# %% [markdown]
# Importing dataframe from: https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=cumulative

# %%
#To import data from a .csv file to a pandas dataframe
# This .csv file was taken from: https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=cumulative

dfraw = pd.read_csv('Data\cumulative_2021.03.02_23.25.21.csv', skiprows=75)
dfraw.head()
# Out:
#       kepid koi_disposition koi_pdisposition  koi_score  koi_fpflag_nt  \
# 0  10797460       CONFIRMED        CANDIDATE      1.000              0
# 1  10797460       CONFIRMED        CANDIDATE      0.969              0
# 2  10811496       CANDIDATE        CANDIDATE      0.000              0
# 3  10848459  FALSE POSITIVE   FALSE POSITIVE      0.000              0
# 4  10854555       CONFIRMED        CANDIDATE      1.000              0
#
#    koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec        koi_disp_prov  \
# 0              0              0              0  q1_q17_dr25_sup_koi
# 1              0              0              0  q1_q17_dr25_sup_koi
# 2              0              0              0  q1_q17_dr25_sup_koi
# 3              1              0              0  q1_q17_dr25_sup_koi
# 4              0              0              0  q1_q17_dr25_sup_koi
#
#    koi_period  ...  koi_srad_err2  koi_smass  koi_smass_err1  koi_smass_err2  \
# 0    9.488036  ...         -0.061      0.919           0.052          -0.046
# 1   54.418383  ...         -0.061      0.919           0.052          -0.046
# 2   19.899140  ...         -0.078      0.961           0.110          -0.121
# 3    1.736952  ...         -0.067      0.836           0.093          -0.077
# 4    2.525592  ...         -0.133      1.095           0.151          -0.136
#
#    koi_sage  koi_sage_err1  koi_sage_err2         ra        dec  koi_kepmag
# 0       NaN            NaN            NaN  291.93423  48.141651      15.347
# 1       NaN            NaN            NaN  291.93423  48.141651      15.347
# 2       NaN            NaN            NaN  297.00482  48.134129      15.436
# 3       NaN            NaN            NaN  285.53461  48.285210      15.597
# 4       NaN            NaN            NaN  288.75488  48.226200      15.509
#
# [5 rows x 69 columns]

# %% [markdown]
# ### Data Exploration

# %%
#Print a concise summary of a DataFrame
#In this way, we can start looking better at our data
dfraw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 69 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   kepid              9564 non-null   int64
#  1   koi_disposition    9564 non-null   object
#  2   koi_pdisposition   9564 non-null   object
#  3   koi_score          8054 non-null   float64
#  4   koi_fpflag_nt      9564 non-null   int64
#  5   koi_fpflag_ss      9564 non-null   int64
#  6   koi_fpflag_co      9564 non-null   int64
#  7   koi_fpflag_ec      9564 non-null   int64
#  8   koi_disp_prov      9564 non-null   object
#  9   koi_period         9564 non-null   float64
#  10  koi_period_err1    9110 non-null   float64
#  11  koi_period_err2    9110 non-null   float64
#  12  koi_time0bk        9564 non-null   float64
#  13  koi_time0bk_err1   9110 non-null   float64
#  14  koi_time0bk_err2   9110 non-null   float64
#  15  koi_time0          9564 non-null   float64
#  16  koi_time0_err1     9110 non-null   float64
#  17  koi_time0_err2     9110 non-null   float64
#  18  koi_eccen          9201 non-null   float64
#  19  koi_eccen_err1     0 non-null      float64
#  20  koi_eccen_err2     0 non-null      float64
#  21  koi_longp          0 non-null      float64
#  22  koi_longp_err1     0 non-null      float64
#  23  koi_longp_err2     0 non-null      float64
#  24  koi_impact         9201 non-null   float64
#  25  koi_impact_err1    9110 non-null   float64
#  26  koi_impact_err2    9110 non-null   float64
#  27  koi_duration       9564 non-null   float64
#  28  koi_duration_err1  9110 non-null   float64
#  29  koi_duration_err2  9110 non-null   float64
#  30  koi_depth          9201 non-null   float64
#  31  koi_depth_err1     9110 non-null   float64
#  32  koi_depth_err2     9110 non-null   float64
#  33  koi_ror            9201 non-null   float64
#  34  koi_ror_err1       9201 non-null   float64
#  35  koi_ror_err2       9201 non-null   float64
#  36  koi_prad           9201 non-null   float64
#  37  koi_prad_err1      9201 non-null   float64
#  38  koi_prad_err2      9201 non-null   float64
#  39  koi_teq            9201 non-null   float64
#  40  koi_teq_err1       0 non-null      float64
#  41  koi_teq_err2       0 non-null      float64
#  42  koi_insol          9243 non-null   float64
#  43  koi_insol_err1     9243 non-null   float64
#  44  koi_insol_err2     9243 non-null   float64
#  45  koi_model_snr      9201 non-null   float64
#  46  koi_tce_plnt_num   9218 non-null   float64
#  47  koi_tce_delivname  9218 non-null   object
#  48  koi_steff          9201 non-null   float64
#  49  koi_steff_err1     9096 non-null   float64
#  50  koi_steff_err2     9081 non-null   float64
#  51  koi_slogg          9201 non-null   float64
#  52  koi_slogg_err1     9096 non-null   float64
#  53  koi_slogg_err2     9096 non-null   float64
#  54  koi_smet           9178 non-null   float64
#  55  koi_smet_err1      9177 non-null   float64
#  56  koi_smet_err2      9177 non-null   float64
#  57  koi_srad           9201 non-null   float64
#  58  koi_srad_err1      9096 non-null   float64
#  59  koi_srad_err2      9096 non-null   float64
#  60  koi_smass          9201 non-null   float64
#  61  koi_smass_err1     9096 non-null   float64
#  62  koi_smass_err2     9096 non-null   float64
#  63  koi_sage           0 non-null      float64
#  64  koi_sage_err1      0 non-null      float64
#  65  koi_sage_err2      0 non-null      float64
#  66  ra                 9564 non-null   float64
#  67  dec                9564 non-null   float64
#  68  koi_kepmag         9563 non-null   float64
# dtypes: float64(60), int64(5), object(4)
# memory usage: 5.0+ MB

# %% [markdown]
# We can notice above the error columns that measure each measurement error of the telescope. To make the exploration simpler, let's ignore those columns for now:

# %%
#To remove the error columns from our dataframe
new_col = [column for column in dfraw.columns if '_err' not in column]

df = dfraw[ new_col ]

df.head()
# Out:
#       kepid koi_disposition koi_pdisposition  koi_score  koi_fpflag_nt  \
# 0  10797460       CONFIRMED        CANDIDATE      1.000              0
# 1  10797460       CONFIRMED        CANDIDATE      0.969              0
# 2  10811496       CANDIDATE        CANDIDATE      0.000              0
# 3  10848459  FALSE POSITIVE   FALSE POSITIVE      0.000              0
# 4  10854555       CONFIRMED        CANDIDATE      1.000              0
#
#    koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec        koi_disp_prov  \
# 0              0              0              0  q1_q17_dr25_sup_koi
# 1              0              0              0  q1_q17_dr25_sup_koi
# 2              0              0              0  q1_q17_dr25_sup_koi
# 3              1              0              0  q1_q17_dr25_sup_koi
# 4              0              0              0  q1_q17_dr25_sup_koi
#
#    koi_period  ...  koi_tce_delivname  koi_steff  koi_slogg  koi_smet  \
# 0    9.488036  ...    q1_q17_dr25_tce     5455.0      4.467      0.14
# 1   54.418383  ...    q1_q17_dr25_tce     5455.0      4.467      0.14
# 2   19.899140  ...    q1_q17_dr25_tce     5853.0      4.544     -0.18
# 3    1.736952  ...    q1_q17_dr25_tce     5805.0      4.564     -0.52
# 4    2.525592  ...    q1_q17_dr25_tce     6031.0      4.438      0.07
#
#    koi_srad  koi_smass  koi_sage         ra        dec  koi_kepmag
# 0     0.927      0.919       NaN  291.93423  48.141651      15.347
# 1     0.927      0.919       NaN  291.93423  48.141651      15.347
# 2     0.868      0.961       NaN  297.00482  48.134129      15.436
# 3     0.791      0.836       NaN  285.53461  48.285210      15.597
# 4     1.046      1.095       NaN  288.75488  48.226200      15.509
#
# [5 rows x 33 columns]

# %%
# Summary statistics for all variables
df.describe(include='all').transpose()
# Out:
#                     count unique                  top  freq            mean  \
# kepid              9564.0    NaN                  NaN   NaN  7690628.327373
# koi_disposition      9564      3       FALSE POSITIVE  4840             NaN
# koi_pdisposition     9564      2       FALSE POSITIVE  4847             NaN
# koi_score          8054.0    NaN                  NaN   NaN        0.480829
# koi_fpflag_nt      9564.0    NaN                  NaN   NaN        0.208595
# koi_fpflag_ss      9564.0    NaN                  NaN   NaN        0.232748
# koi_fpflag_co      9564.0    NaN                  NaN   NaN        0.197512
# koi_fpflag_ec      9564.0    NaN                  NaN   NaN        0.120033
# koi_disp_prov        9564      1  q1_q17_dr25_sup_koi  9564             NaN
# koi_period         9564.0    NaN                  NaN   NaN       75.671358
# koi_time0bk        9564.0    NaN                  NaN   NaN      166.183251
# koi_time0          9564.0    NaN                  NaN   NaN  2454999.183246
# koi_eccen          9201.0    NaN                  NaN   NaN             0.0
# koi_longp             0.0    NaN                  NaN   NaN             NaN
# koi_impact         9201.0    NaN                  NaN   NaN        0.735105
# koi_duration       9564.0    NaN                  NaN   NaN        5.621606
# koi_depth          9201.0    NaN                  NaN   NaN    23791.335898
# koi_ror            9201.0    NaN                  NaN   NaN        0.283646
# koi_prad           9201.0    NaN                  NaN   NaN      102.891778
# koi_teq            9201.0    NaN                  NaN   NaN     1085.385828
# koi_insol          9243.0    NaN                  NaN   NaN     7745.737023
# koi_model_snr      9201.0    NaN                  NaN   NaN      259.895001
# koi_tce_plnt_num   9218.0    NaN                  NaN   NaN        1.243654
# koi_tce_delivname    9218      3      q1_q17_dr25_tce  8054             NaN
# koi_steff          9201.0    NaN                  NaN   NaN      5706.82328
# koi_slogg          9201.0    NaN                  NaN   NaN        4.310157
# koi_smet           9178.0    NaN                  NaN   NaN       -0.124431
# koi_srad           9201.0    NaN                  NaN   NaN        1.728712
# koi_smass          9201.0    NaN                  NaN   NaN        1.023706
# koi_sage              0.0    NaN                  NaN   NaN             NaN
# ra                 9564.0    NaN                  NaN   NaN      292.060163
# dec                9564.0    NaN                  NaN   NaN       43.810433
# koi_kepmag         9563.0    NaN                  NaN   NaN       14.264606
#
#                               std          min            25%          50%  \
# kepid              2653459.080974     757450.0     5556034.25    7906892.0
# koi_disposition               NaN          NaN            NaN          NaN
# koi_pdisposition              NaN          NaN            NaN          NaN
# koi_score                0.476928          0.0            0.0        0.334
# koi_fpflag_nt             4.76729          0.0            0.0          0.0
# koi_fpflag_ss            0.422605          0.0            0.0          0.0
# koi_fpflag_co            0.398142          0.0            0.0          0.0
# koi_fpflag_ec            0.325018          0.0            0.0          0.0
# koi_disp_prov                 NaN          NaN            NaN          NaN
# koi_period            1334.744046     0.241843       2.733684     9.752831
# koi_time0bk              67.91896   120.515914     132.761718   137.224595
# koi_time0                67.91896  2454953.516  2454965.76175  2454970.225
# koi_eccen                     0.0          0.0            0.0          0.0
# koi_longp                     NaN          NaN            NaN          NaN
# koi_impact               3.348832          0.0          0.197        0.537
# koi_duration             6.471554        0.052        2.43775       3.7926
# koi_depth            82242.683149          0.0          159.9        421.1
# koi_ror                  3.306558     0.001289       0.012341     0.021076
# koi_prad              3077.639126         0.08            1.4         2.39
# koi_teq                856.351161         25.0          539.0        878.0
# koi_insol             159204.6652          0.0          20.15        141.6
# koi_model_snr          795.806615          0.0           12.0         23.0
# koi_tce_plnt_num         0.664573          1.0            1.0          1.0
# koi_tce_delivname             NaN          NaN            NaN          NaN
# koi_steff              796.857947       2661.0         5310.0       5767.0
# koi_slogg                0.432606        0.047          4.218        4.438
# koi_smet                 0.282111         -2.5          -0.26         -0.1
# koi_srad                 6.127185        0.109          0.829          1.0
# koi_smass                0.349447          0.0          0.845        0.974
# koi_sage                      NaN          NaN            NaN          NaN
# ra                       4.766657    279.85272      288.66077   292.261125
# dec                      3.601243    36.577381      40.777173    43.677504
# koi_kepmag               1.385448        6.966          13.44        14.52
#
#                             75%          max
# kepid                 9873066.5   12935144.0
# koi_disposition             NaN          NaN
# koi_pdisposition            NaN          NaN
# koi_score                 0.998          1.0
# koi_fpflag_nt               0.0        465.0
# koi_fpflag_ss               0.0          1.0
# koi_fpflag_co               0.0          1.0
# koi_fpflag_ec               0.0          1.0
# koi_disp_prov               NaN          NaN
# koi_period            40.715178  129995.7784
# koi_time0bk          170.694603  1472.522306
# koi_time0          2455003.6945  2456305.522
# koi_eccen                   0.0          0.0
# koi_longp                   NaN          NaN
# koi_impact                0.889      100.806
# koi_duration             6.2765       138.54
# koi_depth                1473.4    1541400.0
# koi_ror                0.095348    99.870651
# koi_prad                  14.93     200346.0
# koi_teq                  1379.0      14667.0
# koi_insol                870.29  10947554.55
# koi_model_snr              78.0       9054.7
# koi_tce_plnt_num            1.0          8.0
# koi_tce_delivname           NaN          NaN
# koi_steff                6112.0      15896.0
# koi_slogg                 4.543        5.364
# koi_smet                   0.07         0.56
# koi_srad                  1.345      229.908
# koi_smass                 1.101        3.735
# koi_sage                    NaN          NaN
# ra                    295.85916    301.72076
# dec                   46.714611     52.33601
# koi_kepmag               15.322       20.003

# %%
#Checking for missing data
df.isna().sum()
# Out:
# kepid                   0
# koi_disposition         0
# koi_pdisposition        0
# koi_score            1510
# koi_fpflag_nt           0
# koi_fpflag_ss           0
# koi_fpflag_co           0
# koi_fpflag_ec           0
# koi_disp_prov           0
# koi_period              0
# koi_time0bk             0
# koi_time0               0
# koi_eccen             363
# koi_longp            9564
# koi_impact            363
# koi_duration            0
# koi_depth             363
# koi_ror               363
# koi_prad              363
# koi_teq               363
# koi_insol             321
# koi_model_snr         363
# koi_tce_plnt_num      346
# koi_tce_delivname     346
# koi_steff             363
# koi_slogg             363
# koi_smet              386
# koi_srad              363
# koi_smass             363
# koi_sage             9564
# ra                      0
# dec                     0
# koi_kepmag              1
# dtype: int64

# %%
# Check duplicated observations
df.loc[df.duplicated(keep=False), :]
# Out:
# Empty DataFrame
# Columns: [kepid, koi_disposition, koi_pdisposition, koi_score, koi_fpflag_nt, koi_fpflag_ss, koi_fpflag_co, koi_fpflag_ec, koi_disp_prov, koi_period, koi_time0bk, koi_time0, koi_eccen, koi_longp, koi_impact, koi_duration, koi_depth, koi_ror, koi_prad, koi_teq, koi_insol, koi_model_snr, koi_tce_plnt_num, koi_tce_delivname, koi_steff, koi_slogg, koi_smet, koi_srad, koi_smass, koi_sage, ra, dec, koi_kepmag]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# As we can see, there are some features with Nan values. So, let's to check wich features have Nan values and how many each has.

# %%
#Checking for missing data
df.isna().sum()
# Out:
# kepid                   0
# koi_disposition         0
# koi_pdisposition        0
# koi_score            1510
# koi_fpflag_nt           0
# koi_fpflag_ss           0
# koi_fpflag_co           0
# koi_fpflag_ec           0
# koi_disp_prov           0
# koi_period              0
# koi_time0bk             0
# koi_time0               0
# koi_eccen             363
# koi_longp            9564
# koi_impact            363
# koi_duration            0
# koi_depth             363
# koi_ror               363
# koi_prad              363
# koi_teq               363
# koi_insol             321
# koi_model_snr         363
# koi_tce_plnt_num      346
# koi_tce_delivname     346
# koi_steff             363
# koi_slogg             363
# koi_smet              386
# koi_srad              363
# koi_smass             363
# koi_sage             9564
# ra                      0
# dec                     0
# koi_kepmag              1
# dtype: int64

# %%
#To check the total number of Nan values that we have in our dataset.
df.isna().sum().sum()
# Out:
# 26031

# %% [markdown]
# Therefore, before doing the treatment of Nan values, let's check the percentage of Nan values in our dataset to see if it is possible to remove them.

# %%
#Total percentage of Nan values in our dataset
null = df.isnull().sum() / len(df) * 100

null[null>0]
# Out:
# koi_score             15.788373
# koi_eccen              3.795483
# koi_longp            100.000000
# koi_impact             3.795483
# koi_depth              3.795483
# koi_ror                3.795483
# koi_prad               3.795483
# koi_teq                3.795483
# koi_insol              3.356336
# koi_model_snr          3.795483
# koi_tce_plnt_num       3.617733
# koi_tce_delivname      3.617733
# koi_steff              3.795483
# koi_slogg              3.795483
# koi_smet               4.035968
# koi_srad               3.795483
# koi_smass              3.795483
# koi_sage             100.000000
# koi_kepmag             0.010456
# dtype: float64

# %% [markdown]
# We can drop koi_sage and koi_longp since are columns with 100% nan values.

# %%
#To drop 'koi_longp' and 'kpo_sage'
new_col.remove('koi_longp')
new_col.remove('koi_sage')

# Some other string columns with clasification information and no relevance:
new_col.remove('koi_tce_delivname')
new_col.remove('koi_disp_prov')

df = df[new_col]

# %% [markdown]
# As we can see above there are a lot of Nan values, by just eliminating them, we would remove a lot of important data and compromise our model.
#
# To better model the missing values, we use the KNN algorithm to fill them.
#
# ## Imputing NaN values with KNN:

# %% [markdown]
# ##### For KNN = 3 (single layer)

# %%
#So we applied the KNN with KNNImputer to numerical features with NaN values
X_knn = df[['koi_score','koi_smass','koi_srad','koi_smet','koi_slogg','koi_steff','koi_tce_plnt_num','koi_model_snr','koi_insol','koi_teq','koi_prad','koi_ror', 'koi_depth','koi_impact','koi_eccen',]]

# %%
# define imputer
imputer = KNNImputer(n_neighbors=3, weights='uniform', metric='nan_euclidean')

# fit on the dataset
imputer.fit(X_knn)

# transform the dataset
Xtrans = imputer.transform(X_knn)

# %%
#To create a new Dataframe with the results that came from applying the knn
df_aux = pd.DataFrame.from_records(columns= X_knn.columns, data = Xtrans)

df_aux.isna().sum().sum()
# Out:
# 0

# %%
#Dataframe without the df_aux columns
df_aux_1 = df.drop(columns = df_aux.columns )

# %% [markdown]
# #### Joining the results:

# %%
#To join the 2 dataframes
df1 = df_aux_1.merge(df_aux, how='outer', left_index=True, right_index=True)

df1.head()
# Out:
#       kepid koi_disposition koi_pdisposition  koi_fpflag_nt  koi_fpflag_ss  \
# 0  10797460       CONFIRMED        CANDIDATE              0              0
# 1  10797460       CONFIRMED        CANDIDATE              0              0
# 2  10811496       CANDIDATE        CANDIDATE              0              0
# 3  10848459  FALSE POSITIVE   FALSE POSITIVE              0              1
# 4  10854555       CONFIRMED        CANDIDATE              0              0
#
#    koi_fpflag_co  koi_fpflag_ec  koi_period  koi_time0bk    koi_time0  ...  \
# 0              0              0    9.488036   170.538750  2455003.539  ...
# 1              0              0   54.418383   162.513840  2454995.514  ...
# 2              0              0   19.899140   175.850252  2455008.850  ...
# 3              0              0    1.736952   170.307565  2455003.308  ...
# 4              0              0    2.525592   171.595550  2455004.596  ...
#
#    koi_steff  koi_tce_plnt_num  koi_model_snr  koi_insol  koi_teq  koi_prad  \
# 0     5455.0               1.0           35.8      93.59    793.0      2.26
# 1     5455.0               2.0           25.8       9.11    443.0      2.83
# 2     5853.0               1.0           76.3      39.30    638.0     14.60
# 3     5805.0               1.0          505.6     891.96   1395.0     33.46
# 4     6031.0               1.0           40.9     926.16   1406.0      2.75
#
#     koi_ror  koi_depth  koi_impact  koi_eccen
# 0  0.022344      615.8       0.146        0.0
# 1  0.027954      874.8       0.586        0.0
# 2  0.154046    10829.0       0.969        0.0
# 3  0.387394     8079.2       1.276        0.0
# 4  0.024064      603.3       0.701        0.0
#
# [5 rows x 29 columns]

# %%
#To check if there are nan values
df1.isna().sum()
# Out:
# kepid               0
# koi_disposition     0
# koi_pdisposition    0
# koi_fpflag_nt       0
# koi_fpflag_ss       0
# koi_fpflag_co       0
# koi_fpflag_ec       0
# koi_period          0
# koi_time0bk         0
# koi_time0           0
# koi_duration        0
# ra                  0
# dec                 0
# koi_kepmag          1
# koi_score           0
# koi_smass           0
# koi_srad            0
# koi_smet            0
# koi_slogg           0
# koi_steff           0
# koi_tce_plnt_num    0
# koi_model_snr       0
# koi_insol           0
# koi_teq             0
# koi_prad            0
# koi_ror             0
# koi_depth           0
# koi_impact          0
# koi_eccen           0
# dtype: int64

# %%
#To delete the nan value of the 'koi_kepmag' feature
df1 = df1.dropna()

# %% [markdown]
# We have now our dataframe free of NaN values:

# %%
df1.to_csv('Data\preprocessed_keppler_data(knn=3).csv', index=False)

# %% [markdown]
# ##### For KNN = 5 (multilayer)

# %%
# define imputer
imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')

# %%
# fit on the dataset
imputer.fit(X_knn)
# Out:
# KNNImputer()

# %%
# transform the dataset
Xtrans = imputer.transform(X_knn)

# %%
#To create a new Dataframe with the results that came from applying the knn
df_aux = pd.DataFrame.from_records(columns= X_knn.columns, data = Xtrans)

# %%
#To check if is everything correct
df_aux.head()
# Out:
#    koi_score  koi_smass  koi_srad  koi_smet  koi_slogg  koi_steff  \
# 0      1.000      0.919     0.927      0.14      4.467     5455.0
# 1      0.969      0.919     0.927      0.14      4.467     5455.0
# 2      0.000      0.961     0.868     -0.18      4.544     5853.0
# 3      0.000      0.836     0.791     -0.52      4.564     5805.0
# 4      1.000      1.095     1.046      0.07      4.438     6031.0
#
#    koi_tce_plnt_num  koi_model_snr  koi_insol  koi_teq  koi_prad   koi_ror  \
# 0               1.0           35.8      93.59    793.0      2.26  0.022344
# 1               2.0           25.8       9.11    443.0      2.83  0.027954
# 2               1.0           76.3      39.30    638.0     14.60  0.154046
# 3               1.0          505.6     891.96   1395.0     33.46  0.387394
# 4               1.0           40.9     926.16   1406.0      2.75  0.024064
#
#    koi_depth  koi_impact  koi_eccen
# 0      615.8       0.146        0.0
# 1      874.8       0.586        0.0
# 2    10829.0       0.969        0.0
# 3     8079.2       1.276        0.0
# 4      603.3       0.701        0.0

# %%
df_aux.isna().sum().sum()
# Out:
# 0

# %%
#Dataframe without the df_aux columns
df_aux_1 = df.drop(columns = df_aux.columns )

# %% [markdown]
# #### Joining the KNN result of NaN values substitution:

# %%
#So we applied the KNN with KNNImputer to numerical features with NaN values
X_knn = df[['koi_score','koi_smass','koi_srad','koi_smet','koi_slogg','koi_steff','koi_tce_plnt_num','koi_model_snr','koi_insol','koi_teq','koi_prad','koi_ror', 'koi_depth','koi_impact','koi_eccen',]]

# %%
#To join the 2 dataframes
df1 = df_aux_1.merge(df_aux, how='outer', left_index=True, right_index=True)

df1.head()
# Out:
#       kepid koi_disposition koi_pdisposition  koi_fpflag_nt  koi_fpflag_ss  \
# 0  10797460       CONFIRMED        CANDIDATE              0              0
# 1  10797460       CONFIRMED        CANDIDATE              0              0
# 2  10811496       CANDIDATE        CANDIDATE              0              0
# 3  10848459  FALSE POSITIVE   FALSE POSITIVE              0              1
# 4  10854555       CONFIRMED        CANDIDATE              0              0
#
#    koi_fpflag_co  koi_fpflag_ec  koi_period  koi_time0bk    koi_time0  ...  \
# 0              0              0    9.488036   170.538750  2455003.539  ...
# 1              0              0   54.418383   162.513840  2454995.514  ...
# 2              0              0   19.899140   175.850252  2455008.850  ...
# 3              0              0    1.736952   170.307565  2455003.308  ...
# 4              0              0    2.525592   171.595550  2455004.596  ...
#
#    koi_steff  koi_tce_plnt_num  koi_model_snr  koi_insol  koi_teq  koi_prad  \
# 0     5455.0               1.0           35.8      93.59    793.0      2.26
# 1     5455.0               2.0           25.8       9.11    443.0      2.83
# 2     5853.0               1.0           76.3      39.30    638.0     14.60
# 3     5805.0               1.0          505.6     891.96   1395.0     33.46
# 4     6031.0               1.0           40.9     926.16   1406.0      2.75
#
#     koi_ror  koi_depth  koi_impact  koi_eccen
# 0  0.022344      615.8       0.146        0.0
# 1  0.027954      874.8       0.586        0.0
# 2  0.154046    10829.0       0.969        0.0
# 3  0.387394     8079.2       1.276        0.0
# 4  0.024064      603.3       0.701        0.0
#
# [5 rows x 29 columns]

# %%
#To check if there are nan values
df1.isna().sum()
# Out:
# kepid               0
# koi_disposition     0
# koi_pdisposition    0
# koi_fpflag_nt       0
# koi_fpflag_ss       0
# koi_fpflag_co       0
# koi_fpflag_ec       0
# koi_period          0
# koi_time0bk         0
# koi_time0           0
# koi_duration        0
# ra                  0
# dec                 0
# koi_kepmag          1
# koi_score           0
# koi_smass           0
# koi_srad            0
# koi_smet            0
# koi_slogg           0
# koi_steff           0
# koi_tce_plnt_num    0
# koi_model_snr       0
# koi_insol           0
# koi_teq             0
# koi_prad            0
# koi_ror             0
# koi_depth           0
# koi_impact          0
# koi_eccen           0
# dtype: int64

# %% [markdown]
# As we can see, we have 1 more nan value. So, let's going to remove it.

# %%
#To delete the nan value of the 'koi_kepmag' feature
df1 = df1.dropna()

# %%
#To check if we don't have more None values
df1.isna().sum().sum()
# Out:
# 0

# %%
#To check dtype of variables
df1.dtypes
# Out:
# kepid                 int64
# koi_disposition      object
# koi_pdisposition     object
# koi_fpflag_nt         int64
# koi_fpflag_ss         int64
# koi_fpflag_co         int64
# koi_fpflag_ec         int64
# koi_period          float64
# koi_time0bk         float64
# koi_time0           float64
# koi_duration        float64
# ra                  float64
# dec                 float64
# koi_kepmag          float64
# koi_score           float64
# koi_smass           float64
# koi_srad            float64
# koi_smet            float64
# koi_slogg           float64
# koi_steff           float64
# koi_tce_plnt_num    float64
# koi_model_snr       float64
# koi_insol           float64
# koi_teq             float64
# koi_prad            float64
# koi_ror             float64
# koi_depth           float64
# koi_impact          float64
# koi_eccen           float64
# dtype: object

# %% [markdown]
# We have now, our dataframe free of NaN values.

# %%
df1.to_csv('Data\preprocessed_keppler_data(knn=5).csv', index=False)

# %% [markdown]
# ### Creating multi-layer target features for multiclass model
#
# Using OneHotEncoding:

# %%
#To apply the one hot enconding on categorical variables
ohc_features = ['koi_disposition']

ohc = OneHotEncoder(sparse=False)

df_ohc = pd.DataFrame(ohc.fit_transform(df1[ohc_features]),index=df1.index, columns=ohc.get_feature_names(ohc_features))

# %%
df_ohc
# Out:
#       koi_disposition_CANDIDATE  koi_disposition_CONFIRMED  \
# 0                           0.0                        1.0
# 1                           0.0                        1.0
# 2                           1.0                        0.0
# 3                           0.0                        0.0
# 4                           0.0                        1.0
# ...                         ...                        ...
# 9559                        0.0                        0.0
# 9560                        1.0                        0.0
# 9561                        0.0                        0.0
# 9562                        1.0                        0.0
# 9563                        0.0                        0.0
#
#       koi_disposition_FALSE POSITIVE
# 0                                0.0
# 1                                0.0
# 2                                0.0
# 3                                1.0
# 4                                0.0
# ...                              ...
# 9559                             1.0
# 9560                             0.0
# 9561                             1.0
# 9562                             0.0
# 9563                             1.0
#
# [9563 rows x 3 columns]

# %%
#To add the new 2 enconding columns to the dataframe
#To join the numerical categorical features to the numerical features
df_new = pd.concat([df1.loc[:, df1.columns.drop(ohc_features)], df_ohc], axis=1)

# %%
#To equal df_new to df1
df1 = df_new.copy()

#Final columns for the model
final_columns = [feature for feature in df1.columns if feature not in ['kepid', 'koi_disposition'] ]

#Final dataframe with the final columns
df1 = df1[final_columns]

df1
# Out:
#      koi_pdisposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE              0              0              0
# 1           CANDIDATE              0              0              0
# 2           CANDIDATE              0              0              0
# 3      FALSE POSITIVE              0              1              0
# 4           CANDIDATE              0              0              0
# ...               ...            ...            ...            ...
# 9559   FALSE POSITIVE              0              1              1
# 9560        CANDIDATE              0              0              0
# 9561   FALSE POSITIVE              0              0              1
# 9562        CANDIDATE              0              0              0
# 9563   FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_time0bk    koi_time0  koi_duration  \
# 0                 0    9.488036   170.538750  2455003.539       2.95750
# 1                 0   54.418383   162.513840  2454995.514       4.50700
# 2                 0   19.899140   175.850252  2455008.850       1.78220
# 3                 0    1.736952   170.307565  2455003.308       2.40641
# 4                 0    2.525592   171.595550  2455004.596       1.65450
# ...             ...         ...          ...          ...           ...
# 9559              0    0.527699   131.705093  2454964.705       3.22210
# 9560              0    1.739849   133.001270  2454966.001       3.11400
# 9561              0    0.681402   132.181750  2454965.182       0.86500
# 9562              0  333.486169   153.615010  2454986.615       3.19900
# 9563              1    4.856035   135.993300  2454968.993       3.07800
#
#              ra  ...  koi_insol  koi_teq  koi_prad   koi_ror  koi_depth  \
# 0     291.93423  ...      93.59    793.0      2.26  0.022344      615.8
# 1     291.93423  ...       9.11    443.0      2.83  0.027954      874.8
# 2     297.00482  ...      39.30    638.0     14.60  0.154046    10829.0
# 3     285.53461  ...     891.96   1395.0     33.46  0.387394     8079.2
# 4     288.75488  ...     926.16   1406.0      2.75  0.024064      603.3
# ...         ...  ...        ...      ...       ...       ...        ...
# 9559  297.18875  ...    4500.53   2088.0     29.35  0.297633     1579.2
# 9560  286.50937  ...    1585.81   1608.0      0.72  0.006379       48.5
# 9561  294.16489  ...    5713.41   2218.0      1.07  0.009444      103.6
# 9562  296.76288  ...      22.68    557.0     19.30  0.022590      639.1
# 9563  297.00977  ...     607.42   1266.0      1.05  0.008076       76.7
#
#       koi_impact  koi_eccen  koi_disposition_CANDIDATE  \
# 0          0.146        0.0                        0.0
# 1          0.586        0.0                        0.0
# 2          0.969        0.0                        1.0
# 3          1.276        0.0                        0.0
# 4          0.701        0.0                        0.0
# ...          ...        ...                        ...
# 9559       1.252        0.0                        0.0
# 9560       0.043        0.0                        1.0
# 9561       0.147        0.0                        0.0
# 9562       0.214        0.0                        1.0
# 9563       0.134        0.0                        0.0
#
#       koi_disposition_CONFIRMED  koi_disposition_FALSE POSITIVE
# 0                           1.0                             0.0
# 1                           1.0                             0.0
# 2                           0.0                             0.0
# 3                           0.0                             1.0
# 4                           1.0                             0.0
# ...                         ...                             ...
# 9559                        0.0                             1.0
# 9560                        0.0                             0.0
# 9561                        0.0                             1.0
# 9562                        0.0                             0.0
# 9563                        0.0                             1.0
#
# [9563 rows x 30 columns]

# %%
df1.to_csv('Data\preprocessed_keppler_data(knn=5)(multilayer).csv', index=False)
